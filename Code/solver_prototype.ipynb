# %%
import importlib

import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as inte
import scipy.constants as c

import axion_mass
from config import model
import g_star
import time_temp
import T_osc_solver
import eom
import runner
import density_plot
import potential

eom = importlib.reload(eom)
density_plot = importlib.reload(density_plot)

# %%
# %time
# solver = eom_solver.EOMSolver(axion_mass.m_a_fox, g_star.shellard_fit, potential.harmonic)
model = eom.Model(axion_mass.m_a_from_chi_general, g_star.borsamyi_table, potential.cosine)
solver = model.get_solver(1e-5, 1e9 * 1e12)
solver.solve_to_osc()
T, theta, dthetadT, n_over_s = solver.find_const_n_over_s()
plt.plot(T, theta)
plt.gca().invert_xaxis()
# %time eom_solver.compute_density_parameter_from_field(T, theta, dthetadT, f_a, m_a_fn, g_model)
# Out:
# CPU times: user 2 µs, sys: 2 µs, total: 4 µs
# Wall time: 5.01 µs
