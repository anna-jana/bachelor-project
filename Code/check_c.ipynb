# %%
import numpy as np
import parameter_estimation_1 as parameter_estimation
import runner
import density_plot
import config

# %%
dens = np.load(config.data_path + "/test_density.npz")
N = 100
workers = 4
theta_i = np.concatenate([
    np.logspace(-5, 0, N // 3),
    np.linspace(1, 3, N // 3 + 2)[1:-1],
    np.linspace(3, np.pi, N // 3),
])
f_a = np.concatenate([
    np.logspace(9, 16, N // 2),
    np.logspace(16, 19, N // 2 + 1)[1:],
]) * 1e9

# %%
density_plot.plot_density(theta_i, f_a, dens)
# Out:
# /home/janik/Documents/bachelor-project/Code/density_plot.py:14: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(f_a / 1e9, theta_i, np.log10(Omega_a_h_sq))

# %%
d = np.load(config.data_path + "/cosine.npz")
theta_i = d["theta_i_s"]
f_a = d["f_a_s"]
Omega = d["Omega_a_h_sq"]
density_plot.plot_density(theta_i, f_a, Omega)
# Out:
# /home/janik/Documents/bachelor-project/Code/density_plot.py:14: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(f_a / 1e9, theta_i, np.log10(Omega_a_h_sq))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3fe76a03cfa0> in <module>()
# ----> 1 density_plot(theta_i, f_a, Omega)
#
# TypeError: 'module' object is not callable
