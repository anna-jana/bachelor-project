# %%
import importlib
import numpy as np
import matplotlib.pyplot as plt
import axion_mass
import g_star
import t_ratio_parameter_estimation
axion_mass = importlib.reload(axion_mass)

# %%
T = np.geomspace(10, 1e6, 300)
f_a = 5e25

# %%
m = [axion_mass.micro_m_a(_T, f_a, 1e2, t_ratio_parameter_estimation.zeta_mean) for _T in T]

# %%
plt.loglog(T, m)
