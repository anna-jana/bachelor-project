# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1.3, 1.3, 300)
eta = 1
T = np.sqrt(3) * eta + 1
l = 1
V = l / 4 * (x**2 - eta**2)**2 + l / 6 * T**2 * x**2
plt.plot(x,V)
